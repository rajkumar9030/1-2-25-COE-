# %%
# !pip install sqlAlchemy
# !pip install mysql-connector
# Out:
# Requirement already satisfied: sqlAlchemy in c:\users\cvr\anaconda3\lib\site-packages (1.4.39)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\cvr\anaconda3\lib\site-packages (from sqlAlchemy) (2.0.1)
# Requirement already satisfied: mysql-connector in c:\users\cvr\anaconda3\lib\site-packages (2.2.9)

# %%
import pandas as pd
from sqlalchemy import create_engine

# Replace the following with your database connection details
username = 'root'  # Your MySQL username
password = '1234'  # Your MySQL password
host = 'localhost'  # Your MySQL host, e.g., 'localhost' or an IP address
database = 'cvr'  # Your MySQL database name

# Create a connection string using SQLAlchemy
connection_string = f'mysql+mysqlconnector://{username}:{password}@{host}/{database}'

# Create an engine
engine = create_engine(connection_string)

# Read data from MySQL into a pandas DataFrame
df_sql = pd.read_sql('SELECT * FROM emp', engine)

# Display the DataFrame
print(df_sql)
# Out:
#     eid          ename   esal          ecity
# 0   283             hi   8000      los vegas
# 1     3            kia  55000        Chicago
# 2     4     Sara White  70000  San Francisco
# 3     5   Mike Johnson  45000          Miami
# 4     6    Alice Green   7000       New York
# 5     7    David Black   8000    Los Angeles
# 6     8     Emma Davis   7500        Chicago
# 7     9   James Wilson   6500  San Francisco
# 8    10     Sophia Lee   8500          Miami
# 9    11    Liam Walker   7000       New York
# 10   12  Olivia Harris   9000    Los Angeles
# 11   13     Noah Clark   6500        Chicago
# 12   14      Ava Lewis   8000  San Francisco
# 13   15     Mason Hall   6700          Miami

# %%
import pandas as pd
from sqlalchemy import create_engine

# Replace the following with your database connection details
username = 'root'  # Your MySQL username
password = '1234'  # Your MySQL password
host = 'localhost'  # Your MySQL host, e.g., 'localhost' or an IP address
database = 'cvr'  # Your MySQL database name

# Create a connection string using SQLAlchemy
connection_string = f'mysql+mysqlconnector://{username}:{password}@{host}/{database}'

# Create an engine
engine = create_engine(connection_string)

# Read data from MySQL into a pandas DataFrame
df_sql = pd.read_sql('SELECT * FROM Colleges', engine)

# Display the DataFrame
print(df_sql)
# Out:
#    CollegeID CollegeName    Location DiversityRatio
# 0          1   College A    New York          35:65
# 1          2   College B  California          25:75
# 2          3   College C       Texas          20:80
# 3          4   College D     Florida          40:60
# 4          5   College E    Illinois          30:70
# 5          6   College F  Washington          50:50
# 6          7   College G     Georgia          15:85
# 7          8   College H        Ohio          45:55

# %%
df2=pd.read_csv("RecruitmentDrive.csv")
df2
# Out:
#    DriveID  CollegeID   DriveDate  CostPerHire  TotalCandidates
# 0      101          1  2023-10-01       4200.0               50
# 1      102          2  2023-10-15       5800.0               40
# 2      103          3  2023-11-01       6500.0               30
# 3      104          4  2023-11-10       4800.0               45
# 4      105          5  2023-11-20       5500.0               35
# 5      106          6  2023-12-01       3900.0               60
# 6      107          7  2023-12-15       7000.0               25
# 7      108          8  2023-12-20       4500.0               55

# %%
df2['CollegeID'].dtype
# Out:
# dtype('int64')

# %%
df3=pd.read_excel('Candidates.xlsx')
df3
# Out:
#     CandidateID  DriveID  CollegeID    CandidateName  OfferAcceptanceRate  \
# 0          1001      101          1         John Doe                   85
# 1          1002      101          1       Jane Smith                   90
# 2          1003      102          2      Alice Brown                   70
# 3          1004      103          3      Bob Johnson                   60
# 4          1005      104          4      Emily Davis                   75
# 5          1006      104          4   Michael Wilson                   80
# 6          1007      105          5   Sarah Martinez                   65
# 7          1008      105          5   David Anderson                   68
# 8          1009      106          6     Laura Taylor                   90
# 9          1010      106          6      James Moore                   88
# 10         1011      107          7    Olivia Thomas                   55
# 11         1012      107          7  William Jackson                   58
# 12         1013      108          8     Sophia White                   80
# 13         1014      108          8    Daniel Harris                   82
#
#     CandidateQualityScore  TimeToHire
# 0                     8.5          45
# 1                     9.0          40
# 2                     7.2          55
# 3                     6.8          60
# 4                     8.0          50
# 5                     8.2          48
# 6                     7.5          65
# 7                     7.0          58
# 8                     9.0          42
# 9                     8.7          40
# 10                    6.5          70
# 11                    6.6          67
# 12                    8.3          47
# 13                    8.5          45

# %%
merge_df=pd.merge(df_sql,df2,on='CollegeID',how='outer')
merge_df
# Out:
#    CollegeID CollegeName    Location DiversityRatio  DriveID   DriveDate  \
# 0          1   College A    New York          35:65      101  2023-10-01
# 1          2   College B  California          25:75      102  2023-10-15
# 2          3   College C       Texas          20:80      103  2023-11-01
# 3          4   College D     Florida          40:60      104  2023-11-10
# 4          5   College E    Illinois          30:70      105  2023-11-20
# 5          6   College F  Washington          50:50      106  2023-12-01
# 6          7   College G     Georgia          15:85      107  2023-12-15
# 7          8   College H        Ohio          45:55      108  2023-12-20
#
#    CostPerHire  TotalCandidates
# 0       4200.0               50
# 1       5800.0               40
# 2       6500.0               30
# 3       4800.0               45
# 4       5500.0               35
# 5       3900.0               60
# 6       7000.0               25
# 7       4500.0               55

# %% [markdown]
# final_merge_df=pd.merge(merge_df,df3,on=['CollegeID','DriveID'],how='outer')
# final_merge_df

# %%
df=pd.merge(merge_df,df3,on=['CollegeID','DriveID'],how='outer') 
df
# Out:
#     CollegeID CollegeName    Location DiversityRatio  DriveID   DriveDate  \
# 0           1   College A    New York          35:65      101  2023-10-01
# 1           1   College A    New York          35:65      101  2023-10-01
# 2           2   College B  California          25:75      102  2023-10-15
# 3           3   College C       Texas          20:80      103  2023-11-01
# 4           4   College D     Florida          40:60      104  2023-11-10
# 5           4   College D     Florida          40:60      104  2023-11-10
# 6           5   College E    Illinois          30:70      105  2023-11-20
# 7           5   College E    Illinois          30:70      105  2023-11-20
# 8           6   College F  Washington          50:50      106  2023-12-01
# 9           6   College F  Washington          50:50      106  2023-12-01
# 10          7   College G     Georgia          15:85      107  2023-12-15
# 11          7   College G     Georgia          15:85      107  2023-12-15
# 12          8   College H        Ohio          45:55      108  2023-12-20
# 13          8   College H        Ohio          45:55      108  2023-12-20
#
#     CostPerHire  TotalCandidates  CandidateID    CandidateName  \
# 0        4200.0               50         1001         John Doe
# 1        4200.0               50         1002       Jane Smith
# 2        5800.0               40         1003      Alice Brown
# 3        6500.0               30         1004      Bob Johnson
# 4        4800.0               45         1005      Emily Davis
# 5        4800.0               45         1006   Michael Wilson
# 6        5500.0               35         1007   Sarah Martinez
# 7        5500.0               35         1008   David Anderson
# 8        3900.0               60         1009     Laura Taylor
# 9        3900.0               60         1010      James Moore
# 10       7000.0               25         1011    Olivia Thomas
# 11       7000.0               25         1012  William Jackson
# 12       4500.0               55         1013     Sophia White
# 13       4500.0               55         1014    Daniel Harris
#
#     OfferAcceptanceRate  CandidateQualityScore  TimeToHire
# 0                    85                    8.5          45
# 1                    90                    9.0          40
# 2                    70                    7.2          55
# 3                    60                    6.8          60
# 4                    75                    8.0          50
# 5                    80                    8.2          48
# 6                    65                    7.5          65
# 7                    68                    7.0          58
# 8                    90                    9.0          42
# 9                    88                    8.7          40
# 10                   55                    6.5          70
# 11                   58                    6.6          67
# 12                   80                    8.3          47
# 13                   82                    8.5          45

# %%
df['CostPerHire'].dtype
# Out:
# dtype('float64')

# %%
print(f"Memory usage :{df.memory_usage(deep=True)}")
# Out:
# Memory usage :Index                    132
# CollegeID                112
# CollegeName              924
# Location                 901
# DiversityRatio           868
# DriveID                  112
# DriveDate                938
# CostPerHire              112
# TotalCandidates          112
# CandidateID              112
# CandidateName            967
# OfferAcceptanceRate      112
# CandidateQualityScore    112
# TimeToHire               112
# dtype: int64

# %%
import numpy as np
df['CollegeID']=df['CollegeID'].astype(np.int16)
df['DriveID']=df['DriveID'].astype(np.int32)

# %%
print(f"Memory usage :{df.memory_usage(deep=True)}")
# Out:
# Memory usage :Index                    132
# CollegeID                 28
# CollegeName              924
# Location                 901
# DiversityRatio           868
# DriveID                   56
# DriveDate                938
# CostPerHire              112
# TotalCandidates          112
# CandidateID              112
# CandidateName            967
# OfferAcceptanceRate      112
# CandidateQualityScore    112
# TimeToHire               112
# dtype: int64

# %%
df['CollegeID'].dtype
# Out:
# dtype('int16')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14 entries, 0 to 13
# Data columns (total 13 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   CollegeID              14 non-null     int16
#  1   CollegeName            14 non-null     object
#  2   Location               14 non-null     object
#  3   DiversityRatio         14 non-null     object
#  4   DriveID                14 non-null     int32
#  5   DriveDate              14 non-null     object
#  6   CostPerHire            14 non-null     float64
#  7   TotalCandidates        14 non-null     int64
#  8   CandidateID            14 non-null     int64
#  9   CandidateName          14 non-null     object
#  10  OfferAcceptanceRate    14 non-null     int64
#  11  CandidateQualityScore  14 non-null     float64
#  12  TimeToHire             14 non-null     int64
# dtypes: float64(2), int16(1), int32(1), int64(4), object(5)
# memory usage: 1.4+ KB

# %%
df['Location']=df['Location'].astype("category")
print(f"Memory usage :{df.memory_usage(deep=True)}")
# Out:
# Memory usage :Index                    132
# CollegeID                 28
# CollegeName              924
# Location                 829
# DiversityRatio           868
# DriveID                   56
# DriveDate                938
# CostPerHire              112
# TotalCandidates          112
# CandidateID              112
# CandidateName            967
# OfferAcceptanceRate      112
# CandidateQualityScore    112
# TimeToHire               112
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14 entries, 0 to 13
# Data columns (total 13 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   CollegeID              14 non-null     int16
#  1   CollegeName            14 non-null     object
#  2   Location               14 non-null     category
#  3   DiversityRatio         14 non-null     object
#  4   DriveID                14 non-null     int32
#  5   DriveDate              14 non-null     object
#  6   CostPerHire            14 non-null     float64
#  7   TotalCandidates        14 non-null     int64
#  8   CandidateID            14 non-null     int64
#  9   CandidateName          14 non-null     object
#  10  OfferAcceptanceRate    14 non-null     int64
#  11  CandidateQualityScore  14 non-null     float64
#  12  TimeToHire             14 non-null     int64
# dtypes: category(1), float64(2), int16(1), int32(1), int64(4), object(4)
# memory usage: 1.7+ KB
